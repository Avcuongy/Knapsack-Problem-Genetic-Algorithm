# %% [markdown]
# ---
#
# <h1>Thí Nghiệm</h1>
#
# ---

# %% [markdown]
# | Thông số ảnh hưởng |
# |----------|
# | Tỷ lệ lai ghép |

# %% [markdown]
# | Kỹ thuật ảnh hưởng |
# |----------|
# | Selection: Rank Selection |
# | Crossover: Arithmetic Crossover  |
# | Mutation: Swap Mutation  |

# %% [markdown]
# <h2>I. Thông số ảnh hưởng</h2>

# %% [markdown]
# <h3>- Tỷ lệ lai ghép. (Crossover Rate) = 0,7 (Biểu đồ trái)</h3>
# <h3>- Tỷ lệ lai ghép. (Crossover Rate) = 0,9 (Biểu đồ phải)</h3>
#   (Số lần chạy bằng nhau)
#
#   (10 lần với testcase 1-4, 20 lần với testcase 5-8)

# %% [markdown]
# - Testcase 1:

# %% [markdown]
# ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png)

# %% [markdown]
# - Testcase 2:

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Testcase 3:

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Testcase 4:

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Testcase 5:

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Testcase 6:

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Testcase 7:

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Testcase 8:

# %% [markdown]
# ![alt text](image.png)![image.png](attachment:image.png)

# %% [markdown]
# <h2>II. Kỹ Thuật ảnh hưởng</h2>

# %% [markdown]
# Biểu đồ trái: ban đầu
#
# Biểu đồ phải: thay đổi
#
# Số lần chạy: 20

# %% [markdown]
# ### - Selection: Rank Selection

# %% [markdown]
# Testcase 1:
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Testcase 8:
#
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### - Crossover: Arithmetic Crossover

# %% [markdown]
# Testcase 1:
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Testcase 8:
#
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### - Mutation: Swap Mutation

# %% [markdown]
# Testcase 1:
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Testcase 8:
#
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)
